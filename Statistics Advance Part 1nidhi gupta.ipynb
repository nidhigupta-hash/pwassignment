# %% [markdown]
# **Statistics Advance Part 1**
#
# **THEORY QUESTIONS:**

# %% [markdown]
# **Q1:What is a random variable in probability theory?**
#
# A random variable is a way to assign numerical values to the outcomes of a random process, helping us analyze and understand uncertainty. Think of it as a bridge between real-world events and mathematical analysis.​
#
# **Example**: Rolling a Die
#
# Imagine rolling a standard six-sided die. The outcome can be any number from 1 to 6. We can define a random variable, say
# 𝑋
# X, to represent this outcome. So, if the die lands on 4, then
# 𝑋
# =
# 4
# X=4. This assignment allows us to study the behavior of the die roll mathematically.​
#
# **Types of Random Variables**
#
# **Discrete Random Variables**: These take on specific, separate values. For instance, the number of heads when flipping three coins can be 0, 1, 2, or 3. Each possible value has an associated probability.​
#
# **Continuous Random Variables**: These can take any value within a range. For example, the exact height of a person can be any value within the human height spectrum. Since there are infinitely many possible heights, we use tools like probability density functions to describe the likelihood of different outcomes.

# %% [markdown]
# **Q2:What are the types of random variables?**
#
# In probability theory and statistics, random variables are primarily categorized into two types: **discrete** and **continuous**.
#
# **Discrete Random Variables:**
# These variables can assume a countable set of distinct values. For example, when rolling a six-sided die, the outcome can be any one of the six integers from 1 to 6. Since the set of possible outcomes is finite and countable, the result of the die roll is a discrete random variable. Other examples include the number of students present in a class or the number of cars passing through a toll booth in an hour. Each of these scenarios involves whole numbers that can be enumerated individually.
#
# **Continuous Random Variables:**
# These variables can take on an uncountable number of values within a given range. For instance, consider measuring the height of students in a school. A student's height could be any value within a certain range, such as 150.2 cm, 160.5 cm, 175.8 cm, and so forth, with infinitely many possible values. Since height can be measured with increasing precision, it represents a continuous random variable. Other examples include the time it takes to run a race or the exact amount of milk in a jug. These measurements can vary smoothly over a continuum of values.

# %% [markdown]
# **Q3:What is the difference between discrete and continuous distributions?**
#
# In probability theory and statistics, **discrete** and **continuous** distributions describe how probabilities are assigned to different types of random variables.
#
# **Discrete Distributions:**
# - **Definition:** A discrete distribution applies to scenarios where the set of possible outcomes is countable, such as a finite or countably infinite list of distinct values.
# - **Probability Assignment:** Probabilities are assigned to individual outcomes. The sum of probabilities for all possible outcomes equals one.
# - **Example:** Consider rolling a six-sided die. The possible outcomes are {1, 2, 3, 4, 5, 6}, each with a probability of 1/6. The probability of rolling a specific number, say 4, is 1/6.
#
# **Continuous Distributions:**
# - **Definition:** A continuous distribution applies when the set of possible outcomes is uncountable, typically corresponding to intervals of real numbers.
# - **Probability Assignment:** Probabilities are assigned to intervals rather than individual outcomes. The probability of the variable taking an exact value is zero; instead, probabilities are determined over ranges of values.
# - **Example:** Consider measuring the height of individuals. Heights can take any value within a range (e.g., between 150 cm and 200 cm). The probability of a person being exactly 170.000... cm tall is zero, but we can calculate the probability of a height falling within an interval, such as between 170 cm and 175 cm.
#
# **Key Differences:**
# - **Nature of Outcomes:** Discrete distributions deal with countable outcomes, while continuous distributions involve uncountable, infinite outcomes within a range.
# - **Probability Calculation:** In discrete distributions, probabilities are calculated for specific values; in continuous distributions, probabilities are calculated over intervals.
# - **Representation:** Discrete distributions are often represented by probability mass functions (PMFs), whereas continuous distributions are represented by probability density functions (PDFs).

# %% [markdown]
# **Q4:What are probability distribution functions (PDF)?**
#
# In probability, the term "Probability Distribution Function" can refer to different functions depending on the context:​
#
# **For Discrete Random Variables:** The function is called a Probability Mass Function (PMF). It assigns probabilities to specific, countable outcomes. For example, when rolling a six-sided die, the PMF gives the probability for each face (1 through 6) appearing.​
#
# **For Continuous Random Variables:** The function is known as a Probability Density Function (PDF). Instead of assigning probabilities to specific outcomes, it describes the likelihood of the variable falling within a particular range. For instance, the PDF can indicate how likely it is for a person's height to be between 150 cm and 160 cm.

# %% [markdown]
# **Q5:How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?**
#
# A Cumulative Distribution Function (CDF) provides the cumulative probability that a random variable takes on a value less than or equal to a specific point. In simpler terms, it tells you the probability that the outcome will fall within a certain range from the lowest possible value up to your point of interest.​
#
# For discrete variables, the CDF sums up the probabilities from the PMF up to a certain value. For continuous variables, the CDF integrates the area under the PDF curve up to that point.​
#
# In summary, while PMFs and PDFs provide the likelihood of specific outcomes or ranges, CDFs give the accumulated probability up to a certain value, offering a comprehensive view of the distribution.

# %% [markdown]
# **Q6:What is a discrete uniform distribution?**
#
# A Discrete Uniform Distribution is a probability distribution where a finite number of outcomes are equally likely. Each outcome has the same probability of occurring.​
#
# Example: Imagine rolling a fair six-sided die. Each face (1 through 6) has an equal chance of landing face up, so the die roll follows a discrete uniform distribution.

# %% [markdown]
# **Q7:What are the key properties of a Bernoulli distribution?**
#
# A Bernoulli Distribution represents a random experiment with exactly two possible outcomes: "success" (usually coded as 1) and "failure" (coded as 0).​
#
# **Key Properties:**
#
# **Two Outcomes :** Only "success" and "failure."​
#
# **Single Trial:** The experiment is conducted once.​
#
# **Probability of Success (p):** The likelihood of a "success" occurring.​
#
# **Probability of Failure (1-p):** The likelihood of a "failure" occurring.

# %% [markdown]
# **Q8:What is the binomial distribution, and how is it used in probability?**
#
# he Binomial Distribution models the number of successes in a fixed number of independent Bernoulli trials (repeated experiments), each with the same probability of success.​
#
# **Key Characteristics:**
#
# **Fixed Number of Trials (n): **The experiment is repeated n times.​
#
#
# **Independent Trials:** The outcome of one trial doesn't affect another.​
#
# **Constant Probability (p):** The probability of success remains the same in each trial.​
#
# **Example:** Tossing a fair coin 10 times and counting how many times it lands on heads. Here, each toss is a Bernoulli trial, and the total count of heads follows a binomial distribution.

# %% [markdown]
# **Q9:What is the Poisson distribution and where is it applied?**
#
# The **Poisson distribution** is a discrete probability distribution that models the number of times an event occurs within a fixed interval of time, space, or any other continuum, under specific conditions. It's particularly useful for modeling events that happen independently and with a known constant mean rate.
#
# **Mathematical Definition:**
#
# If an event can occur multiple times within a fixed interval and the occurrences are independent, the probability of observing exactly \( k \) events is given by the Poisson formula:
#
# \[ P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!} \]
#
# Where:
#
# - \( k \) = number of occurrences (0, 1, 2, ...).
# - \( \lambda \) = expected number of occurrences in the interval.
# - \( e \) = Euler's number (approximately 2.71828).
# - \( k! \) = factorial of \( k \).
#
# The parameter \( \lambda \) represents both the mean and the variance of the distribution.
#
# **Key Characteristics:**
#
# - **Discrete Events:** The Poisson distribution applies to scenarios where events are countable and occur at distinct points in time or space.
# - **Independence:** Each event occurs independently of others.
# - **Constant Average Rate:** The average rate (\( \lambda \)) of event occurrence is constant over the interval.
# - **Non-Simultaneity:** Two events cannot occur at exactly the same instant.
#
# **Applications:**
#
# The Poisson distribution is widely used across various fields to model the occurrence of rare events over a specified interval. Some common applications include:
#
# - **Telecommunications:** Modeling the number of phone calls received by a call center per minute.
# - **Astronomy:** Counting the number of photons hitting a detector in a fixed time period.
# - **Biology:** Estimating the number of mutations in a strand of DNA over a certain length.
# - **Finance:** Predicting the number of defaults on loans within a portfolio over a year.
# - **Traffic Engineering:** Analyzing the number of cars passing through a toll booth in an hour.
# - **Sports Analytics:** Determining the number of goals scored in a soccer match.
#
# For instance, in finance, the Poisson distribution can help estimate the likelihood of a certain number of defaults occurring in a loan portfolio over a specified period, aiding in risk assessment and management.
#
# Understanding and applying the Poisson distribution allows professionals and researchers to predict and analyze the frequency of events in various domains, facilitating informed decision-making and strategic planning.

# %% [markdown]
# **Q10:What is a continuous uniform distribution?**
#
# A **continuous uniform distribution** is a probability distribution in which all outcomes within a specified range \([a, b]\) are equally likely. This results in a constant probability density function (PDF) over the interval \([a, b]\), forming a rectangular shape when graphed.
#
# **Key Properties:**
#
# - **Probability Density Function (PDF):** For a random variable \(X\) uniformly distributed between \(a\) and \(b\), the PDF is:
#   \[ f(x) = \frac{1}{b - a} \quad \text{for } a \leq x \leq b \]
#
# - **Mean (Expected Value):** The average value is \( \mu = \frac{a + b}{2} \).
#
# - **Variance:** The measure of dispersion is \( \sigma^2 = \frac{(b - a)^2}{12} \).
#
# **Applications:**
#
# Continuous uniform distributions are commonly used in scenarios where outcomes are equally probable within a range, such as:
#
# - **Random Number Generation:** Producing numbers that are uniformly distributed between two bounds.
#
# - **Simulation Modeling:** Assigning equal likelihood to all possible outcomes within a specified range in simulations.
#
# - **Quality Control:** Modeling measurement errors that are equally likely to fall anywhere within a specified range.

# %% [markdown]
# **Q11:What are the characteristics of a normal distribution?**
#
# A normal distribution, often called a "bell curve," is a way to describe how data points are spread out in many natural situations. Its main features include:​
#
# **Symmetry:** The left and right sides of the curve are mirror images, meaning data is evenly distributed around the center.​
#
# **Peak at the Mean:** The highest point of the curve represents the average (mean) value, which is also the most common value.​
# Statlect
#
# **Equal Mean, Median, and Mode:**In a normal distribution, the mean (average), median (middle value), and mode (most frequent value) are all the same.​
#
# **Tails Extend Infinitely:**The ends of the curve, called tails, approach but never touch the horizontal axis, indicating that extreme values are possible but rare.

# %% [markdown]
# **Q12:What is the standard normal distribution, and why is it important?**
#
# The standard normal distribution is a special type of normal distribution that has:​
#
# **A Mean of 0:** The center of the curve is at zero.​
#
# **A Standard Deviation of 1:** This measures the spread of the data; in this case, it's standardized to one.​
#
# This standardization is crucial because it allows us to compare different data sets and perform statistical analyses more easily. By converting any normal distribution to the standard normal distribution through a process called standardization, we can use a common scale to interpret and compare scores from different contexts.

# %% [markdown]
# **Q13:What is the Central Limit Theorem (CLT), and why is it critical in statistics?**
#
# The Central Limit Theorem is a fundamental principle in statistics that states:​
#
# When you take sufficiently large random samples from any population, the average (mean) of those samples will form a normal distribution, regardless of the original population's distribution.​
#
# This is critical because it allows statisticians to make predictions and inferences about a population using sample data. Even if the underlying data isn't normally distributed, the averages of large samples will be, enabling the use of normal distribution techniques in various analyses.

# %% [markdown]
# **Q14: How does the Central Limit Theorem relate to the normal distribution?**
#
# The Central Limit Theorem connects to the normal distribution by explaining how the distribution of sample means becomes normal as sample sizes increase. This relationship is vital because many statistical methods rely on normality. Thanks to the CLT, we can apply these methods to sample means, even when the original data doesn't follow a normal distribution, as long as the sample size is large enough.

# %% [markdown]
# **Q15:What is the application of Z statistics in hypothesis testingWhat is the application of Z statistics in hypothesis testing?**
#
# In hypothesis testing, Z-statistics (or Z-scores) are used when comparing a sample to a known population, especially when the population's standard deviation is known. They help determine how unusual or typical a sample result is under the assumption that the null hypothesis is true.​
#
# For example, if we want to test whether a new teaching method affects student performance, we can calculate a Z-score to see how the sample mean compares to the known population mean. If the Z-score is significantly high or low, it may indicate that the teaching method has a real effect, leading us to reject the null hypothesis. ​
#
#  These concepts provides a solid foundation for analyzing data and making informed decisions based on statistical evidence.

# %% [markdown]
# **Q16:How do you calculate a Z-score, and what does it represent?**
#
# A Z-score tells us how far a particular data point is from the average (mean) of a dataset, measured in units of standard deviation. In simple terms, it shows how "unusual" or "typical" a value is within a set of data.​
#
# **Formula to Calculate a Z-Score:**
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#  ​
#
# **Where:**
#
# 𝑋
# X = the data point you're examining.​
#
# 𝜇
# μ = the mean (average) of the dataset.​
#
# 𝜎
# σ = the standard deviation of the dataset.​
#
# **What the Z-Score Indicates:**
#
# A Z-score of 0 means the data point is exactly at the mean.​
#
# A positive Z-score indicates the data point is above the mean.​
#
# A negative Z-score indicates the data point is below the mean.​
#
# For example, if a student's test score has a Z-score of +2, it means they scored two standard deviations above the average score. This helps us understand how a particular score compares to the overall performance.

# %% [markdown]
# **Q17:What are point estimates and interval estimates in statistics?**
#
# When we want to infer something about a whole population based on a sample, we use estimates. There are two main types:​
#
# **Point Estimate: **This is a single value that serves as our best guess for an unknown population parameter. For instance, using the average height from a sample group to estimate the average height of the entire population. While straightforward, point estimates don't convey how confident we are in that estimate.​
#
# **Interval Estimate:** Instead of a single value, this provides a range (or interval) within which we believe the population parameter lies. This range is constructed around the point estimate and gives us a better sense of the estimate's reliability.​
#
# In summary, point estimates give a specific value, while interval estimates provide a range that likely includes the true population parameter.

# %% [markdown]
# **Q18:What is the significance of confidence intervals in statistical analysis?**
#
# A confidence interval is a type of interval estimate that gives a range of values, derived from sample data, that is likely to contain the value of an unknown population parameter. It provides more information than a point estimate by indicating the precision and reliability of the estimate.​
# GeeksforGeeks
#
# **Why Confidence Intervals Are Important:**
#
# **Measure of Uncertainty:** They offer a range that likely includes the true population parameter, giving us an idea of the estimate's accuracy.​
#
# **Informed Decision-Making:** By understanding the range within which the true value lies, researchers and policymakers can make better decisions.​
#
# For example, if we estimate that the average time to complete a task is 30 minutes with a 95% confidence interval of 28 to 32 minutes, it means we're 95% confident that the true average falls within this range.

# %% [markdown]
# **Q19:What is the relationship between a Z-score and a confidence interval?**
#
# Z-scores play a crucial role in constructing confidence intervals, especially when dealing with normally distributed data.​
#
# **How They Relate:**
#
# **Determining the Interval:** To create a confidence interval, we often use Z-scores corresponding to the desired confidence level. For instance, a 95% confidence level corresponds to a Z-score of approximately 1.96.​
#
# **Calculating the Margin of Error:** The Z-score is multiplied by the standard error (which measures the variability in the sample) to determine the margin of error. This margin is then added and subtracted from the point estimate to form the confidence interval.​
#
# In essence, Z-scores help us quantify how much we can expect our sample estimate to vary from the true population parameter, allowing us to construct meaningful confidence intervals.

# %% [markdown]
# **Q20:How are Z-scores used to compare different distributions?**
#
# Z-scores standardize different datasets, making them comparable even if they have different means and standard deviations.​
#
# **Applications:**
#
# **Comparing Individual Scores:** If two students take different tests with different scoring systems, converting their scores to Z-scores allows us to determine who performed better relative to their respective groups.​
#
# **Identifying Outliers:** Z-scores help in detecting data points that are significantly different from the rest, which might indicate anomalies or errors.​
#
# By converting raw scores into Z-scores, we can objectively compare and interpret data from diverse sources on a common scale.

# %% [markdown]
# **Q21:What are the assumptions for applying the Central Limit Theorem?**
#
# The Central Limit Theorem (CLT) is a fundamental principle in statistics that explains why many distributions tend to be approximately normal (bell-shaped) when we average a large number of independent observations. For the CLT to hold true, certain conditions or assumptions must be met:​
#
# **Random Sampling:** The data should be collected through a process where each member of the population has an equal chance of being selected. This ensures that the sample represents the population without bias.​
#
# **Independence:** Each observation in the sample must be independent of the others. This means that the outcome of one observation doesn't influence or change the outcome of another.​
#
# **Sample Size:** While the CLT suggests that larger sample sizes lead to a sampling distribution that is approximately normal, a common guideline is that a sample size of 30 or more is considered sufficient for the CLT to apply. However, if the original population distribution is heavily skewed or has outliers, a larger sample size might be necessary to achieve a normal approximation.​
#
# **Population Size:** When sampling without replacement (meaning once an individual is selected, they aren't put back into the population for possible reselection), the sample size should be relatively small compared to the population size. A general rule is that the sample should not exceed 10% of the population to maintain the independence assumption.​
#
# Meeting these assumptions helps ensure that the sampling distribution of the sample mean will be approximately normal, allowing us to make reliable inferences about the population.

# %% [markdown]
# **Q22:What is the concept of expected value in a probability distribution?**
#
# In probability and statistics, the expected value is essentially the long-term average or mean value of a random variable over numerous trials or occurrences. It provides a measure of the center of the distribution of the variable.​
#
# For a discrete random variable (one that has specific, countable outcomes), the expected value is calculated by:
#
# Multiplying each possible outcome by its corresponding probability.​
#
# Summing all these products together.​
#
# **Formula:**
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# [
# 𝑥
# ×
# 𝑃
# (
# 𝑥
# )
# ]
# E(X)=∑[x×P(x)]​
#
# **Where:**
#
# 𝐸
# (
# 𝑋
# )
# E(X) is the expected value.​
#
# 𝑥
# x represents each possible outcome.​
#
# 𝑃
# (
# 𝑥
# )
# P(x) is the probability of each outcome occurring.​
#
# **Example:**
#
# Consider a simple game where you flip a fair coin:
#
# If it lands on Heads, you win $2.​
#
# If it lands on Tails, you win nothing ($0).​
#
# **The probabilities are:**
#
# 𝑃
# (
# Heads
# )
# =
# 0.5
# P(Heads)=0.5​
#
# 𝑃
# (
# Tails
# )
# =
# 0.5
# P(Tails)=0.5​
#
# **Calculating the expected value:**
#
# 𝐸
# (
# 𝑋
# )
# =
# (
# 2
# ×
# 0.5
# )
# +
# (
# 0
# ×
# 0.5
# )
# =
# 1
# +
# 0
# =
# 1
# E(X)=(2×0.5)+(0×0.5)=1+0=1​
#
# This means that, on average, you can expect to win $1 per coin flip over many flips.

# %% [markdown]
# **Q23: How does a probability distribution relate to the expected outcome of a random variable?**
#
# A probability distribution describes how the values of a random variable are distributed, indicating which outcomes are more or less likely. The expected value is a key characteristic of this distribution, representing the average outcome you'd anticipate over a large number of trials.​
#
# **Relationship:**
#
# The probability distribution provides a complete picture of all possible outcomes and their associated probabilities.​
#
# The expected value summarizes this information into a single number, reflecting the central tendency or average outcome based on the distribution.​
#
# Understanding the expected value helps in predicting the average result of random processes and making informed decisions in uncertain situations.

# %% [markdown]
# **PRACTICAL QUESTION:**

# %%
#Q1:Write a Python program to generate a random variable and display its value.
import random

# Generate a random integer between 1 and 100
random_number = random.randint(1, 100)

# Display the generated random number
print(f"Generated random number: {random_number}")
# Out:
# Generated random number: 52

# %%
#Q2:Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range for the discrete uniform distribution
low = 1  # Inclusive lower bound
high = 7  # Exclusive upper bound (for values 1 through 6)

# Create the discrete uniform distribution object
distribution = randint(low, high)

# Generate the values within the specified range
x = np.arange(low, high)

# Calculate the PMF for these values
pmf_values = distribution.pmf(x)

# Plot the PMF
plt.bar(x, pmf_values, width=0.6, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Probability Mass Function of Discrete Uniform Distribution')
plt.xticks(x)
plt.ylim(0, 1)
plt.show()

# %%
#Q3:Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.
def bernoulli_pmf(k, p):
    """
    Calculate the Probability Mass Function of a Bernoulli distribution.

    Parameters:
    k (int): The outcome, either 0 or 1.
    p (float): The probability of success (0 <= p <= 1).

    Returns:
    float: Probability of observing the outcome k.
    """
    if k not in [0, 1]:
        raise ValueError("The outcome k must be 0 or 1.")
    if not (0 <= p <= 1):
        raise ValueError("The probability p must be between 0 and 1.")
    return p**k * (1 - p)**(1 - k)

# Example usage:
success_probability = 0.7
print("P(X=1):", bernoulli_pmf(1, success_probability))  # Output: P(X=1): 0.7
print("P(X=0):", bernoulli_pmf(0, success_probability))  # Output: P(X=0): 0.3
# Out:
# P(X=1): 0.7
# P(X=0): 0.30000000000000004

# %%
#Q4:Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10      # Number of trials
p = 0.5     # Probability of success
size = 1000 # Number of experiments

# Generate binomial distribution data
data = np.random.binomial(n, p, size)

# Plot the histogram
plt.hist(data, bins=np.arange(0, n+2)-0.5, edgecolor='black', density=True)
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n+1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Q5:Create a Poisson distribution and visualize it using Python.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the average rate (λ) of events
lambda_value = 5

# Generate x values (number of events)
x = np.arange(0, 15)

# Calculate the PMF for each x value
pmf_values = poisson.pmf(x, lambda_value)

# Plot the Poisson PMF
plt.bar(x, pmf_values, color='skyblue')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution (λ={lambda_value})')
plt.show()

# %%
#Q6:Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range for the discrete uniform distribution
low = 1  # Inclusive lower bound
high = 7  # Exclusive upper bound (values will be 1 through 6)

# Create the discrete uniform distribution object
dist = randint(low, high)

# Generate the values within the specified range
x = np.arange(low, high)

# Calculate the CDF for these values
cdf_values = dist.cdf(x)

# Plot the CDF
plt.step(x, cdf_values, where='post', color='blue', marker='o')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function of Discrete Uniform Distribution')
plt.xticks(x)
plt.ylim(0, 1.1)
plt.grid(True)
plt.show()

# %%
#Q7:Generate a continuous uniform distribution using NumPy and visualize it.
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the uniform distribution
low = 0.0   # Lower bound
high = 1.0  # Upper bound
size = 1000 # Number of random samples

# Generate random samples from a uniform distribution
samples = np.random.uniform(low, high, size)

# Plot the histogram
plt.hist(samples, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black')
plt.title('Continuous Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

# Plot the probability density function (PDF)
plt.axhline(y=1/(high - low), color='red', linestyle='--', label='Theoretical PDF')
plt.legend()

plt.show()

# %%
#Q8:Simulate data from a normal distribution and plot its histogram.
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the normal distribution
mean = 0       # Mean of the distribution
std_dev = 1    # Standard deviation of the distribution
size = 1000    # Number of samples

# Generate random samples from a normal distribution
samples = np.random.normal(loc=mean, scale=std_dev, size=size)

# Plot the histogram
plt.hist(samples, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black')
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#Q9:Write a Python function to calculate Z-scores from a dataset and plot them.
import numpy as np
import matplotlib.pyplot as plt

def calculate_z_scores(data):
    """
    Calculate the Z-scores for a dataset.

    Parameters:
    data (array-like): The input data array.

    Returns:
    np.array: The Z-scores of the data.
    """
    mean = np.mean(data)
    std_dev = np.std(data)
    # Calculate the Z-score for each element
    z_scores = (data - mean) / std_dev
    return z_scores

def plot_z_scores(z_scores):
    """
    Plot the Z-scores as a line plot with markers.

    Parameters:
    z_scores (array-like): The Z-scores to plot.
    """
    plt.figure(figsize=(10, 6))
    plt.plot(z_scores, marker='o', linestyle='-', color='blue')
    plt.title('Z-scores of the Dataset')
    plt.xlabel('Index')
    plt.ylabel('Z-score')
    plt.axhline(0, color='black', linewidth=0.8, linestyle='--')
    plt.grid(True)
    plt.show()

# Example usage:
if __name__ == '__main__':
    # Create a sample dataset (e.g., 100 random values from a normal distribution)
    data = np.random.normal(loc=50, scale=10, size=100)

    # Calculate Z-scores
    z_scores = calculate_z_scores(data)

    # Print the calculated Z-scores
    print("Z-scores:", z_scores)

    # Plot the Z-scores
    plot_z_scores(z_scores)
# Out:
# Z-scores: [ 0.23561465  0.39897744 -0.66446959  0.53752081 -0.29589504  0.50120707
#  -0.05424441  0.09924558  0.17796932  0.54684871  0.86425246 -1.03153049
#  -0.1616281   1.52078998 -1.65321139 -0.50089784  0.51092036 -0.2969546
#  -1.01634294 -1.13536312 -1.74137096 -0.13349453 -1.51271468  0.54247247
#  -0.05978053 -0.08632841 -0.40837605 -0.83271557 -1.50555115 -0.0994899
#  -1.12833644 -0.56753246  1.75177331  0.17950181  1.01222815 -0.52394816
#   2.44804529  0.04611166  0.90025942  0.1847895  -1.50470146 -0.70513542
#   0.22902509  1.71231234 -1.24210568 -0.54029113  0.70503211 -0.82405616
#  -0.49015045 -1.87303879 -0.75281949  0.41626057 -0.92676018  1.53628777
#   1.28035636  1.59386456 -0.44723941  0.54235433  0.83274014  1.63911824
#   0.13183862  0.08293652  0.99902045  1.3469784  -0.47890212 -0.96023637
#   0.99346777 -0.07255271 -2.45871443  1.23351952  0.50756193 -0.20888166
#  -0.52289451  1.52885165 -0.09600822 -1.09782207 -0.43273127  0.48007983
# ...

# %%
#Q10: Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate data from an exponential distribution
np.random.seed(42)  # For reproducibility
population_size = 100000
population = np.random.exponential(scale=2.0, size=population_size)

# Step 2: Draw multiple random samples and compute their means
sample_size = 50  # Number of observations in each sample
num_samples = 1000  # Number of samples to draw
sample_means = []

for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

# Step 3: Plot the histogram of sample means
plt.figure(figsize=(10, 6))
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='g', edgecolor='black')
plt.title('Distribution of Sample Means (Sample Size = 50) from an Exponential Distribution')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#Q15:Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate data from a normal distribution
np.random.seed(42)  # For reproducibility
population_mean = 50
population_std_dev = 10
population_size = 100000
population = np.random.normal(loc=population_mean, scale=population_std_dev, size=population_size)

# Step 2: Draw multiple random samples and compute their means
sample_size = 30  # Number of observations in each sample
num_samples = 1000  # Number of samples to draw
sample_means = []

for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

# Step 3: Plot the histogram of sample means
plt.figure(figsize=(10, 6))
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='b', edgecolor='black')
plt.title('Distribution of Sample Means (Sample Size = 30) from a Normally Distributed Population')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
#Q16:Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1):
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Plots the standard normal distribution (mean = 0, standard deviation = 1).
    """
    # Generate x values from -4 to 4 in increments of 0.01
    x = np.arange(-4, 4, 0.01)

    # Calculate the standard normal distribution's probability density function (PDF)
    y = norm.pdf(x, 0, 1)

    # Create the plot
    plt.figure(figsize=(8, 5))
    plt.plot(x, y, color='blue', linewidth=2)
    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.xlabel('X-axis')
    plt.ylabel('Probability Density')
    plt.grid(True)
    plt.show()

# Call the function to plot the standard normal distribution
plot_standard_normal_distribution()

# %%
#Q17:Generate random variables and calculate their corresponding probabilities using the binomial distribution.
import numpy as np
from scipy.stats import binom

# Parameters for the binomial distribution
n = 10      # Number of trials
p = 0.5     # Probability of success in each trial
size = 1000 # Number of random variables to generate

# Step 1: Generate random variables from the binomial distribution
random_variables = np.random.binomial(n, p, size)

# Step 2: Calculate the probability mass function (PMF) for each possible outcome
# Define the range of possible outcomes
x = np.arange(0, n+1)

# Calculate PMF values for each outcome
pmf_values = binom.pmf(x, n, p)

# Display the results
print("Outcome\tProbability")
for outcome, prob in zip(x, pmf_values):
    print(f"{outcome}\t{prob:.4f}")
# Out:
# Outcome	Probability
# 0	0.0010
# 1	0.0098
# 2	0.0439
# 3	0.1172
# 4	0.2051
# 5	0.2461
# 6	0.2051
# 7	0.1172
# 8	0.0439
# 9	0.0098
# 10	0.0010

# %%
#Q18:Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.
import numpy as np
from scipy.stats import norm

def calculate_z_score(data_point, data):
    """
    Calculate the Z-score for a given data point within a dataset.

    Parameters:
    data_point (float): The data point for which the Z-score is calculated.
    data (list or numpy array): The dataset containing numerical values.

    Returns:
    float: The Z-score of the data point.
    """
    mean = np.mean(data)
    std_dev = np.std(data)
    z_score = (data_point - mean) / std_dev
    return z_score

def compare_to_standard_normal(z_score):
    """
    Compare the Z-score to the standard normal distribution by calculating
    the cumulative probability.

    Parameters:
    z_score (float): The Z-score to compare.

    Returns:
    float: The cumulative probability corresponding to the Z-score.
    """
    cumulative_prob = norm.cdf(z_score)
    return cumulative_prob

# Example usage:
# Sample dataset
data = [50, 52, 53, 54, 55, 56, 57, 58, 59, 60]
data_point = 55

# Calculate Z-score
z = calculate_z_score(data_point, data)
print(f"Z-score for data point {data_point}: {z:.2f}")

# Compare to standard normal distribution
cumulative_probability = compare_to_standard_normal(z)
print(f"Cumulative probability for Z-score {z:.2f}: {cumulative_probability:.4f}")
# Out:
# Z-score for data point 55: -0.13
# Cumulative probability for Z-score -0.13: 0.4477

# %%
#Q19:Implement hypothesis testing using Z-statistics for a sample dataset.
import numpy as np
from statsmodels.stats.weightstats import ztest

# Sample data: Test scores of 50 students
sample_data = np.array([88, 92, 85, 90, 86, 89, 91, 87, 84, 93,
                        85, 90, 88, 86, 91, 89, 92, 87, 85, 90,
                        86, 88, 89, 91, 87, 84, 93, 85, 90, 88,
                        86, 91, 89, 92, 87, 85, 90, 86, 88, 89,
                        91, 87, 84, 93, 85, 90, 88, 86, 91, 89])

# Population parameters
population_mean = 85  # Known population mean
population_std = 5    # Known population standard deviation

# Perform one-sample Z-test
z_stat, p_value = ztest(sample_data, value=population_mean, alternative='two-sided')

# Output results
print(f"Z-statistic: {z_stat:.2f}")
print(f"P-value: {p_value:.4f}")

# Decision
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
else:
    print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")
# Out:
# Z-statistic: 9.01
# P-value: 0.0000
# Reject the null hypothesis: The sample mean is significantly different from the population mean.

# %%
#Q20:Create a confidence interval for a dataset using Python and interpret the result.
import numpy as np
from scipy import stats

# Sample dataset: Heights of individuals in centimeters
data = [165, 170, 168, 172, 175, 178, 180, 182, 185, 188]

# Step 1: Calculate the sample mean and standard error of the mean (SEM)
sample_mean = np.mean(data)
sem = stats.sem(data)  # SEM = standard deviation / sqrt(sample size)

# Step 2: Define the confidence level
confidence_level = 0.95

# Step 3: Calculate the confidence interval
# For small sample sizes (n < 30), use the t-distribution
degrees_freedom = len(data) - 1
confidence_interval = stats.t.interval(confidence_level, degrees_freedom, loc=sample_mean, scale=sem)

# Output the results
print(f"Sample Mean: {sample_mean:.2f} cm")
print(f"{confidence_level*100}% Confidence Interval: ({confidence_interval[0]:.2f} cm, {confidence_interval[1]:.2f} cm)")
# Out:
# Sample Mean: 176.30 cm
# 95.0% Confidence Interval: (170.87 cm, 181.73 cm)

# %%
#Q21:Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.
import numpy as np
from scipy import stats

# Step 1: Generate data from a normal distribution
np.random.seed(42)  # For reproducibility
sample_size = 50
population_mean = 100
population_std = 15
sample_data = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)

# Step 2: Calculate sample mean and standard error of the mean (SEM)
sample_mean = np.mean(sample_data)
sem = stats.sem(sample_data)

# Step 3: Define the confidence level
confidence_level = 0.95

# Step 4: Calculate the confidence interval
degrees_freedom = sample_size - 1
confidence_interval = stats.t.interval(confidence_level, degrees_freedom, loc=sample_mean, scale=sem)

# Output the results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"{confidence_level*100}% Confidence Interval: ({confidence_interval[0]:.2f}, {confidence_interval[1]:.2f})")
# Out:
# Sample Mean: 96.62
# 95.0% Confidence Interval: (92.64, 100.60)

# %%
#Q22:Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mu = 0      # Mean
sigma = 1   # Standard deviation

# Data points
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# PDF calculation
pdf = norm.pdf(x, mu, sigma)

# Plotting
plt.plot(x, pdf, label=f'Normal Distribution\n$\mu={mu}$, $\sigma={sigma}$')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Normal Distribution PDF')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Q23: Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the average rate of occurrence (λ)
lambda_ = 4  # For example, an average of 4 events per interval

# Generate a range of event counts
k_values = np.arange(0, 15)

# Calculate the CDF for each k value
cdf_values = poisson.cdf(k_values, mu=lambda_)

# Plotting the CDF
plt.step(k_values, cdf_values, where='post', label=f'λ = {lambda_}')
plt.xlabel('Number of Events (k)')
plt.ylabel('Cumulative Probability')
plt.title('Poisson Cumulative Distribution Function')
plt.grid(True)
plt.legend()
plt.show()

# %%
#Q24:Simulate a random variable using a continuous uniform distribution and calculate its expected value.
import numpy as np

# Parameters
a = 5   # Lower bound
b = 15  # Upper bound

# Generate random samples
sample_size = 10000
samples = np.random.uniform(low=a, high=b, size=sample_size)

# Calculate sample mean
sample_mean = np.mean(samples)

# Calculate theoretical expected value
expected_value = (a + b) / 2

# Display results
print(f"Sample Mean: {sample_mean}")
print(f"Theoretical Expected Value: {expected_value}")
# Out:
# Sample Mean: 9.943433092707549
# Theoretical Expected Value: 10.0

# %%
#Q25:Write a Python program to compare the standard deviations of two datasets and visualize the difference.
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate sample datasets
heights = np.random.normal(loc=170, scale=10, size=1000)
weights = np.random.normal(loc=70, scale=15, size=1000)

# Calculate means and standard deviations
mean_heights = np.mean(heights)
std_heights = np.std(heights, ddof=1)

mean_weights = np.mean(weights)
std_weights = np.std(weights, ddof=1)

print(f"Mean of Heights: {mean_heights:.2f} cm")
print(f"Standard Deviation of Heights: {std_heights:.2f} cm")
print(f"Mean of Weights: {mean_weights:.2f} kg")
print(f"Standard Deviation of Weights: {std_weights:.2f} kg")

# Visualize the distributions
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(heights, bins=30, color='skyblue', alpha=0.7)
plt.axvline(mean_heights, color='red', linestyle='dashed', linewidth=1)
plt.axvline(mean_heights - std_heights, color='green', linestyle='dashed', linewidth=1)
plt.axvline(mean_heights + std_heights, color='green', linestyle='dashed', linewidth=1)
plt.title('Distribution of Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.legend({'Mean': 'red', '±1 Std Dev': 'green'})

plt.subplot(1, 2, 2)
plt.hist(weights, bins=30, color='lightcoral', alpha=0.7)
plt.axvline(mean_weights, color='red', linestyle='dashed', linewidth=1)
plt.axvline(mean_weights - std_weights, color='green', linestyle='dashed', linewidth=1)
plt.axvline(mean_weights + std_weights, color='green', linestyle='dashed', linewidth=1)
plt.title('Distribution of Weights')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')
plt.legend({'Mean': 'red', '±1 Std Dev': 'green'})

plt.tight_layout()
plt.show()
#Q25:Write a Python program to compare the standard deviations of two datasets and visualize the difference.
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate sample datasets
heights = np.random.normal(loc=170, scale=10, size=1000)
weights = np.random.normal(loc=70, scale=15, size=1000)

# Calculate means and standard deviations
mean_heights = np.mean(heights)
std_heights = np.std(heights, ddof=1)

mean_weights = np.mean(weights)
std_weights = np.std(weights, ddof=1)

print(f"Mean of Heights: {mean_heights:.2f} cm")
print(f"Standard Deviation of Heights: {std_heights:.2f} cm")
print(f"Mean of Weights: {mean_weights:.2f} kg")
print(f"Standard Deviation of Weights: {std_weights:.2f} kg")

# Visualize the distributions
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(heights, bins=30, color='skyblue', alpha=0.7)
plt.axvline(mean_heights, color='red', linestyle='dashed', linewidth=1)
plt.axvline(mean_heights - std_heights, color='green', linestyle='dashed', linewidth=1)
plt.axvline(mean_heights + std_heights, color='green', linestyle='dashed', linewidth=1)
plt.title('Distribution of Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.legend(['Mean', '±1 Std Dev'])

plt.subplot(1, 2, 2)
plt.hist(weights, bins=30, color='lightcoral', alpha=0.7)
plt.axvline(mean_weights, color='red', linestyle='dashed', linewidth=1)
plt.axvline(mean_weights - std_weights, color='green', linestyle='dashed', linewidth=1)
plt.axvline(mean_weights + std_weights, color='green', linestyle='dashed', linewidth=1)
plt.title('Distribution of Weights')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')
plt.legend(['Mean', '±1 Std Dev'])

plt.tight_layout()
plt.show()

# Perform F-test
f_statistic = (std_heights**2) / (std_weights**2)
p_value = stats.f.cdf(f_statistic, len(heights)-1, len(weights)-1)

print(f"F-statistic: {f_statistic:.2f}")
print(f"P-value: {p_value:.3f}")
# Out:
# Mean of Heights: 170.26 cm
# Standard Deviation of Heights: 10.21 cm
# Mean of Weights: 70.03 kg
# Standard Deviation of Weights: 14.39 kg
# Mean of Heights: 169.52 cm
# Standard Deviation of Heights: 9.70 cm
# Mean of Weights: 70.12 kg
# Standard Deviation of Weights: 15.01 kg
# F-statistic: 0.42
# P-value: 0.000

# %%
#Q26:Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.
import numpy as np
from scipy.stats import iqr

# Parameters for the normal distribution
mean = 0
std_dev = 1
size = 1000

# Generate the dataset
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Calculate the range
data_range = np.ptp(data)
print(f"Range: {data_range:.2f}")

# Calculate the interquartile range (IQR)
data_iqr = iqr(data)
print(f"Interquartile Range (IQR): {data_iqr:.2f}")
# Out:
# Range: 6.28
# Interquartile Range (IQR): 1.31

# %%
#Q27: Implement Z-score normalization on a dataset and visualize its transformation.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Set random seed for reproducibility
np.random.seed(42)

# Generate a normally distributed dataset with 1000 samples
data = np.random.normal(loc=50, scale=15, size=1000)

# Visualize the original data distribution
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='blue', alpha=0.7)
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Apply Z-score normalization
normalized_data = zscore(data)

# Visualize the normalized data distribution
plt.subplot(1, 2, 2)
plt.hist(normalized_data, bins=30, color='green', alpha=0.7)
plt.title('Z-Score Normalized Data Distribution')
plt.xlabel('Z-Score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
#Q28:Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.
import numpy as np
from scipy.stats import skew, kurtosis

# Set random seed for reproducibility
np.random.seed(42)

# Generate a dataset of 1000 samples from a normal distribution
data = np.random.normal(loc=0, scale=1, size=1000)

# Function to calculate skewness and kurtosis
def calculate_skewness_kurtosis(data):
    skewness = skew(data, bias=False)
    kurt = kurtosis(data, bias=False, fisher=True)
    return skewness, kurt

# Calculate skewness and kurtosis
skewness, kurt = calculate_skewness_kurtosis(data)

# Display the results
print(f"Skewness: {skewness:.4f}")
print(f"Excess Kurtosis: {kurt:.4f}")
# Out:
# Skewness: 0.1170
# Excess Kurtosis: 0.0726
